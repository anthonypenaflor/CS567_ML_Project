# %%
pip install transformers pandas openpyxl
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
from google.colab import drive
import pandas as pd
from transformers import pipeline

# Mount Google Drive
drive.mount('/content/drive')

# Function to set up the generator pipeline with a specified model
def setup_generator(model_name="gpt2"):  # Using GPT-2 for demonstration
    generator = pipeline('text-generation', model=model_name)
    return generator

# Set up text generation model
generator = setup_generator()
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# For the original train data

# Function to generate text based on prompts, with better error handling
def generate_articles(generator, prompts, max_length=1000):
    articles = []
    batch_size = 20  # Adjust based on your testing and system capabilities
    for i in range(0, len(prompts), batch_size):
        batch_prompts = prompts[i:i + batch_size]
        print(f"Generating articles for batch starting with prompt: {batch_prompts[0][:50]}...")
        generated_texts = generator(batch_prompts, max_length=max_length, num_return_sequences=1)
        for index, generated in enumerate(generated_texts):
            if isinstance(generated, dict):
                articles.append((batch_prompts[index], generated['generated_text']))
                print(f"Article generated from prompt: {generated['generated_text'][:50]}")
            else:
                for item in generated:
                    articles.append((batch_prompts[index], item['generated_text']))
                    print(f"Article generated from prompt: {item['generated_text'][:50]}")
    return articles

# Function to extract the first 50 words
def get_first_50_words(texts):
    prompts = []
    for text in texts:
        words = text.split()[:50]  # Split the text and take the first 50 words
        prompt = ' '.join(words)  # Join the words back into a single string
        prompts.append(prompt)
    return prompts

# Main function to load data, generate articles, and save them
def main(input_file, output_file):
    # Load data
    df = pd.read_excel(input_file)

    df = df.iloc[551:826]  # Adjust index as 0-based for Python (row 551 to 825)

    texts = df.iloc[:, 0].tolist()  # Assuming texts are in the first column

    # Extract the first 50 words as prompts
    prompts = get_first_50_words(texts)

    # Generate articles
    articles = generate_articles(generator, prompts)

    # Save generated articles to a new DataFrame and then to Excel
    articles_df = pd.DataFrame(articles, columns=['Prompt', 'Generated Article'])
    articles_df.to_excel(output_file, index=False)
    print(f"Generated articles saved to {output_file}")

# File paths (adjust as necessary)
input_file = '/content/drive/My Drive/ML Project data/train_essays_modified.xlsx'
output_file = '/content/drive/My Drive/ML Project data/output_file_GPT-2(O3).xlsx'

if __name__ == "__main__":
    main(input_file, output_file)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Generating articles for batch starting with prompt: To get from point A to point B, whether it be from...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: To get from point A to point B, whether it be from
# Article generated from prompt: Dear Senator, I believe that is is time to get rid
# Article generated from prompt: To whom this may concern, The "winner takes all" s
# Article generated from prompt: Limiting car uses will change the environment in a
# Article generated from prompt: In todays society driving or riding in a car is a
# Article generated from prompt: "All of our development since world war II has bee
# Article generated from prompt: Innocent and young, children grow accuitomed to th
# Article generated from prompt: Dear State Senator, The Electoral College is an an
# Article generated from prompt: There are many advantages to limiting car usage ar
# Article generated from prompt: Dear Senator, We the people of the United States o
# Article generated from prompt: Cars have been used as the main means of transport
# Article generated from prompt: Many people now a days use cars, trucks, buses or
# Article generated from prompt: There are plenty of advantages fellow citizens get
# Article generated from prompt: It is becoming increasingly evident that one part
# Article generated from prompt: How does the Electoral College affect the selectio
# Article generated from prompt: Dear State Senator, Everyone has their very own op
# Article generated from prompt: Electoral College? Dear state senator, i been read
# Article generated from prompt: The Electoral College is not a fair system for vot
# Article generated from prompt: Bustling traffic fills every available lane on the
# Article generated from prompt: Here, in the United States, birthplace of the Mode
# Generating articles for batch starting with prompt: I think that we should change from the Electoral C...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: I think that we should change from the Electoral C
# Article generated from prompt: Dear Senator, I'd like to take some of your time t
# Article generated from prompt: The advantages of limiting car usage would be less
# Article generated from prompt: Dear state senator, I think that we should change
# Article generated from prompt: Automobiles are the key essential to people's ever
# Article generated from prompt: Limiting car usage is great for people and the env
# Article generated from prompt: I think people should stop relying on their cars s
# Article generated from prompt: Congestion, the amount of car traffic in a specifi
# Article generated from prompt: Do you know the advantages and the disadvantages o
# Article generated from prompt: Dear my. senator The Electoral college process con
# Article generated from prompt: Many European countries have been making a move to
# Article generated from prompt: The electoral college should be thrown out and the
# Article generated from prompt: The electoral college must go down! The electoral
# Article generated from prompt: Dear State Senator, I am writing you a letter in r
# Article generated from prompt: As you may know, the Electoral College consists of
# Article generated from prompt: The Electoral College is broken, and with another
# Article generated from prompt: Forida senator, I argue to remove the Electoral Co
# Article generated from prompt: The Electoral College, its something that can chan
# Article generated from prompt: The effects of greenhouse gas emission began to ta
# Article generated from prompt: As of right now, imagining an automobilefree world
# Generating articles for batch starting with prompt: All around the world in places such as the United ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: All around the world in places such as the United
# Article generated from prompt: Dear Senator name of Florida's senator, I am write
# Article generated from prompt: The thought of limiting car usage may sound ridicu
# Article generated from prompt: Dear Governor, I believe we need to keep the Elect
# Article generated from prompt: As a citizen of the United States, I have the righ
# Article generated from prompt: Dear Senator Nelson, In recent years, many people
# Article generated from prompt: Can you imagine living in a place where there is n
# Article generated from prompt: Why even the bestlaid defenses of the system are w
# Article generated from prompt: Dear State Senator, 12315 I have a very strongly w
# Article generated from prompt: " The Electoral College is a process, not a place.
# Article generated from prompt: Thousands of Americans use their own car or a vehi
# Article generated from prompt: Why do we keep this despised method of choosing th
# Article generated from prompt: There are many advantages of having limitations in
# Article generated from prompt: How is the election of the president of the U.S.?
# Article generated from prompt: The automobile has been a staple in human history
# Article generated from prompt: As of April 2013 the number of miles driven per pe
# Article generated from prompt: The electoral College is something in the United S
# Article generated from prompt: Most people think that driving is a top priority.
# Article generated from prompt: Cars are used used in everyday life but they may b
# Article generated from prompt: Imagine this you're in a very populated city. Lets
# Generating articles for batch starting with prompt: All around the world air pollution is a major prob...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: All around the world air pollution is a major prob
# Article generated from prompt: Although limiting car usage may seem out of the or
# Article generated from prompt: People think about today's world as the era of tec
# Article generated from prompt: Dear Senator, I firmly believe that we should keep
# Article generated from prompt: Cars, though useful, have negative impacts on the
# Article generated from prompt: The Electoral College has been around for quite so
# Article generated from prompt: Todays society uses automotive vehicles almost eve
# Article generated from prompt: Has it ever seem hotter than it usually has to you
# Article generated from prompt: Dear State Senator, The Electoral College is widel
# Article generated from prompt: I argue in favor of keeping the Electoral College.
# Article generated from prompt: An Electoral College is a process established in t
# Article generated from prompt: Statistics show that when a community has given up
# Article generated from prompt: Dear State Senator, We all know that the president
# Article generated from prompt: The electoral college is not a good thing and it c
# Article generated from prompt: "The Electoral College is a process, not a place".
# Article generated from prompt: Cars, the pride and joy of many people. They may l
# Article generated from prompt: Dear Senator, I feel the need to eliminate the Ele
# Article generated from prompt: Our country's history with cars date back a few ce
# Article generated from prompt: It's not a secret that we as humans use cars to ge
# Article generated from prompt: Dear Mr. Senator, The Electoral College has served
# Generating articles for batch starting with prompt: The limitation of car use provides many improvemen...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: The limitation of car use provides many improvemen
# Article generated from prompt: Dear Florida senator, It is in the interest of you
# Article generated from prompt: Dear Senator, I think that Electoral College is no
# Article generated from prompt: The breeze of the late summer air, it's fragrance
# Article generated from prompt: If someone wishes to travel somewhere, such as a n
# Article generated from prompt: The Electoral College should be abolished because
# Article generated from prompt: The main way the majority of the people in our com
# Article generated from prompt: Cars are not the most important thing in our lives
# Article generated from prompt: "The founding fathers established it in the consti
# Article generated from prompt: The number of positive connotations that limiting
# Article generated from prompt: Dear senator, if I may speak for the people I thin
# Article generated from prompt: Car usage could easily help detoriate waste and po
# Article generated from prompt: Dear state senator, I ask you to change the voting
# Article generated from prompt: Dear state senator, After researching the Electora
# Article generated from prompt: This country is built on democracy, the idea that
# Article generated from prompt: Imagine that the president the majority of the peo
# Article generated from prompt: Limiting car usage can have many beneficial outcom
# Article generated from prompt: The way we should change the way we choose our Uni
# Article generated from prompt: Many cities are experiencing perhaps the biggest e
# Article generated from prompt: Nowadays, there is one sure thing we depend on to
# Generating articles for batch starting with prompt: Dear Senator, Every four years, citizens of the Un...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear Senator, Every four years, citizens of the Un
# Article generated from prompt: If I were to choose between keeping the electoral
# Article generated from prompt: global warming has been said to be a problem for y
# Article generated from prompt: Do you know what the Electoral College is? It's a
# Article generated from prompt: Dear our state Senator, I am writing to you for no
# Article generated from prompt: The car is a staple in modern day society by many
# Article generated from prompt: Every year, the residents of Bogota, Colombia cele
# Article generated from prompt: Imagine a World where the people didn't have a say
# Article generated from prompt: Personal automobiles and cars have played a major
# Article generated from prompt: Fellow citizens should know about the advantages o
# Article generated from prompt: Have you ever realized how driving everywhere isn'
# Article generated from prompt: A day without driving your car? who can't do that.
# Article generated from prompt: In America, cars are considered an important neces
# Article generated from prompt: Some people may view car limitations as bad or inc
# Article generated from prompt: To you, a car may mean no more than just getting f
# Article generated from prompt: Cars have been a part of our culture and society f
# Article generated from prompt: The electoral college is a very important this to
# Article generated from prompt: Dear Mr.Mrs. senator I believe that you should con
# Article generated from prompt: The works of a car have created wonders to people
# Article generated from prompt: Is the Electoral College a good thing? A Majority
# Generating articles for batch starting with prompt: There are many advantages to limiting car usage, f...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: There are many advantages to limiting car usage, f
# Article generated from prompt: Dear Senator, I believe that we should let our nat
# Article generated from prompt: How important is a persons car to them? Do they re
# Article generated from prompt: "The electoral college is a process, not a place.
# Article generated from prompt: An industrial world without cars may seem to be ag
# Article generated from prompt: Dear State Senator, The Electoral College has been
# Article generated from prompt: imagine a world, twenty or so years from now, comp
# Article generated from prompt: Many people wonder whether or not cars should be b
# Article generated from prompt: Electoral College is where we pick our state elect
# Article generated from prompt: America was built upon the foundation known as dem
# Article generated from prompt: Places around the world such as Germany, America,
# Article generated from prompt: Transportation is a must in today's society, and c
# Article generated from prompt: Cars have been used almost everywhere around the w
# Article generated from prompt: All of these articles share the central idea of mi
# Article generated from prompt: Our Founding Fathers created a new concept of a wa
# Article generated from prompt: Voting has always been something special for almos
# Article generated from prompt: There are many advantages to limiting car usage. T
# Article generated from prompt: The electoral college system has been part of Amer
# Article generated from prompt: Cars have been around for over hundred years. They
# Article generated from prompt: We as Americans have the right to vote for who we
# Generating articles for batch starting with prompt: Attention my fellow citizens, we should limit car ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Attention my fellow citizens, we should limit car
# Article generated from prompt: Imagine a world completely pollution free. A world
# Article generated from prompt: Cars are a huge advantage in traveling. They can g
# Article generated from prompt: Americans have rights, I understand that, but many
# Article generated from prompt: Advantages of limiting car usage? Is that even pos
# Article generated from prompt: The majority of people use some sort of gas transp
# Article generated from prompt: In today's modern world, new inventions are shapin
# Article generated from prompt: When you think of voting for president, do you thi
# Article generated from prompt: Cars are a part of everyday life. You use them to
# Article generated from prompt: Limiting car usage could have many advantages on o
# Article generated from prompt: Many places around the world are limiting the usag
# Article generated from prompt: Dear State Senator, After conducting studies on th
# Article generated from prompt: The electoral college is flawed and in result, wor
# Article generated from prompt: Most people were raised on fairness what everybody
# Article generated from prompt: Florida Senators, The Electoral College is an unfa
# Article generated from prompt: Automobile accidents are very common in suburbs an
# Article generated from prompt: Since World War II, driving has been the center of
# Article generated from prompt: BOOM! CRASH! BANG! "911, what's your emergency?" "
# Article generated from prompt: A world without cars is a world we should all want
# Article generated from prompt: Cars are an integral part of many peoples lives ar
# Generating articles for batch starting with prompt: To begin , i think that the electoral college is n...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: To begin , i think that the electoral college is n
# Article generated from prompt: Walking into the voting booth "...every four years
# Article generated from prompt: Cars have become an important part of our world. F
# Article generated from prompt: Nowadays does everyone rely on cars frequently, an
# Article generated from prompt: Abolishing the electoral college would be the best
# Article generated from prompt: What If i told you that instead of having the elec
# Article generated from prompt: There are so many ways that limiting car usage is
# Article generated from prompt: The Electoral College has been used for years. I a
# Article generated from prompt: Dear Senator, The Electoral College is unfair to n
# Article generated from prompt: Why does electoral college still have its defender
# Article generated from prompt: Dear State Senator, After experiencing the dispute
# Article generated from prompt: Dear Senator, People have different opinions on th
# Article generated from prompt: Keeping the Electoral College is not smart for the
# Article generated from prompt: I think that limiting car usage is great for the e
# Article generated from prompt: A "car free" community has many advantages. They w
# Article generated from prompt: Cars may be a good source of travel, but, unknown
# Article generated from prompt: Although we rely on cars as a primary means of tra
# Article generated from prompt: The culture of the cars is a easier way of transpo
# Article generated from prompt: Dear The Florida State Senator, In our nation, we
# Article generated from prompt: " All of our development since World War 2 has bee
# Generating articles for batch starting with prompt: Dear dumb Republican , The Electoral College is st...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear dumb Republican , The Electoral College is st
# Article generated from prompt: If you were told on some days of the week that you
# Article generated from prompt: The president of the united states is one of the m
# Article generated from prompt: Cars are becoming a must in today's society. In so
# Article generated from prompt: In Vauban, Germany, citizens have made the decisio
# Article generated from prompt: For years, the United States has been mass produci
# Article generated from prompt: Dear Florida senator, this letter is to discuss my
# Article generated from prompt: In today's society there is neverending controvers
# Article generated from prompt: Dear State Senator, Many people go back and forth
# Article generated from prompt: While there have been presidents that have run wit
# Article generated from prompt: arguments on whether the state senator should favo
# Article generated from prompt: Dear Senator, If one could sum up the definition o
# Article generated from prompt: Many cities and countries are starting a new trend
# Article generated from prompt: Dear Senator, "The Electoral College is a process,
# Article generated from prompt: Who doesn't have a car now days? It seems like eve
# Article generated from prompt: Dear state senator, I'm writing to you today regar
# Article generated from prompt: What is the one thing a citizen of the united stat
# Article generated from prompt: Smog. Gas. Pollution. Many countries dont allow fo
# Article generated from prompt: The Automobile Industry has done nothing but grow
# Article generated from prompt: Cars have been a huge advancement in technology in
# Generating articles for batch starting with prompt: The electoral college is how presidents get electe...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: The electoral college is how presidents get electe
# Article generated from prompt: Ever since it was first invented, the automobile h
# Article generated from prompt: Dear Florida Senator, I can't help but notice the
# Article generated from prompt: The meaning of a democracy is that the people vote
# Article generated from prompt: Dear Senator, I believe that the United States des
# Article generated from prompt: Ford, Volkswagen, Kia, and Chevy's... while these
# Article generated from prompt: After reading a few articles explaining the Electo
# Article generated from prompt: We cuiiently live in a woild dependent on machines
# Article generated from prompt: The elector college is a controversial subject tod
# Article generated from prompt: I believe we the people should be able to vote for
# Article generated from prompt: Dear State Senator, we should not keep the Elector
# Article generated from prompt: Dear Senator PROPER_NAME, The purpose of this lett
# Article generated from prompt: I believe that disbanding electoral college would
# Article generated from prompt: Dear State Senator, The Electoral College has been
# Article generated from prompt: Limiting car usage would be great for both you and
# Article generated from prompt: Although the usage of motorized vehicles such as c
# Article generated from prompt: Cars have been an important part of transportation
# Article generated from prompt: Many countries world wide have gone "carfree" due
# Article generated from prompt: Cars are used for transporting from place to place
# Article generated from prompt: In 2000 when Al Gore got more individual votes the
# Generating articles for batch starting with prompt: What is your point of view on this argument that w...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: What is your point of view on this argument that w
# Article generated from prompt: In years past, the number of people interested in,
# Article generated from prompt: As we should know, "the Electoral College is a pro
# Article generated from prompt: When it comes to voting citizens from all over the
# Article generated from prompt: Many of us are used to getting somewhere by simply
# Article generated from prompt: I would say that we keep the Electoral College bec
# Article generated from prompt: Cars have always been used to get from point A to
# Article generated from prompt: Dear Senator, Presidential elections are closer th
# Article generated from prompt: The Electoral College is not fair and should be ab
# Article generated from prompt: Dear me. Senator, ever since the Presidential Elec
# Article generated from prompt: The Electoral College has been here for many years
# Article generated from prompt: Some people believe that the electoral college sho
# Article generated from prompt: Dear Florida Senator, There is a major problem in
# Article generated from prompt: Dear Florida state senator, The Electoral College
# Article generated from prompt: The Election System should be changed to popular v
# Article generated from prompt: Go outside and take a deep breath, as it is right
# Article generated from prompt: Imagine that it's 6:00am, Monday 2026 and you wake
# Article generated from prompt: Reducing the amount of cars used would benefit the
# Article generated from prompt: The Electoral College should be kept for the votin
# Article generated from prompt: The senate should remove the Electoral college and
# Generating articles for batch starting with prompt: Dear state senator, The Electoral College should b...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear state senator, The Electoral College should b
# Article generated from prompt: The articles explain that the limited use of cars
# Article generated from prompt: We all know that driving makes life easier in term
# Article generated from prompt: There is many different advantages to limiting car
# Article generated from prompt: Dear Florida State Senator, The Electoral College
# Article generated from prompt: The Electoral College is a process that has been u
# Article generated from prompt: Everyday when you wake up and get ready for work t
# Article generated from prompt: Cars have always seemed to be a necessity to peopl
# Article generated from prompt: Cities have come to the realization of how much po
# Article generated from prompt: Dear State Senator, it is more favorable to keep t
# Article generated from prompt: Dear Florida state senator, I highly suggest we ke
# Article generated from prompt: Dear senator, Every one has a voice and they all w
# Article generated from prompt: Although you may think of your car as a necessity,
# Article generated from prompt: Electoral college is a dictator, boss, or lottery!
# Article generated from prompt: Dear Senator, I feel that we should change using t
# Article generated from prompt: Mercedes, BMW, Jaguar, and Audi. What do these car
# Article generated from prompt: While there have been efforts in the past two deca
# Article generated from prompt: The most basic and persistent form of transportati
# Article generated from prompt: To whom it may concern, The growing debate on whet
# Article generated from prompt: Do you want to live in a place where the air is po
# Generating articles for batch starting with prompt: Freedom to chose our leader is nothing more than a...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Freedom to chose our leader is nothing more than a
# Article generated from prompt: Dear Mrs. Senaitor, The Elecitoral College is unfa
# Article generated from prompt: There was a time when cars were a new invention th
# Article generated from prompt: I write this to the Senator of Florida. Every four
# Article generated from prompt: A relevant topic in today's society that many peop
# Article generated from prompt: Cars have been the main focus of development for m
# Article generated from prompt: Since the 1950's everyone's dream was to have a ni
# Article generated from prompt: Our country, the United States of America, needs a
# Article generated from prompt: To tohe stoatoe and tohe stoatoe's countory, tohe
# Article generated from prompt: As we get older we want to travel to more places a
# Article generated from prompt: Throughout the past century car usage has exploded
# Article generated from prompt: Dear Mr. Senator, The Electoral College is ruining
# Article generated from prompt: Everyone assumes that the best way of transportati
# Article generated from prompt: In the year 2000 there was a presidential election
# Article generated from prompt: There is a growing movement in lots of western cou
# Generated articles saved to /content/drive/My Drive/ML Project data/output_file_GPT-2(O3).xlsx
