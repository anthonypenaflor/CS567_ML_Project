# %%
pip install transformers pandas openpyxl
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
from google.colab import drive
import pandas as pd
from transformers import pipeline

# Mount Google Drive
drive.mount('/content/drive')

# Function to set up the generator pipeline with a specified model
def setup_generator(model_name="gpt2"):  # Using GPT-2 for demonstration
    generator = pipeline('text-generation', model=model_name)
    return generator

# Set up text generation model
generator = setup_generator()
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# For the original train data

# Function to generate text based on prompts, with better error handling
def generate_articles(generator, prompts, max_length=1000):
    articles = []
    batch_size = 20  # Adjust based on your testing and system capabilities
    for i in range(0, len(prompts), batch_size):
        batch_prompts = prompts[i:i + batch_size]
        print(f"Generating articles for batch starting with prompt: {batch_prompts[0][:50]}...")
        generated_texts = generator(batch_prompts, max_length=max_length, num_return_sequences=1)
        for index, generated in enumerate(generated_texts):
            if isinstance(generated, dict):
                articles.append((batch_prompts[index], generated['generated_text']))
                print(f"Article generated from prompt: {generated['generated_text'][:50]}")
            else:
                for item in generated:
                    articles.append((batch_prompts[index], item['generated_text']))
                    print(f"Article generated from prompt: {item['generated_text'][:50]}")
    return articles

# Function to extract the first 50 words
def get_first_50_words(texts):
    prompts = []
    for text in texts:
        words = text.split()[:50]  # Split the text and take the first 50 words
        prompt = ' '.join(words)  # Join the words back into a single string
        prompts.append(prompt)
    return prompts

# Main function to load data, generate articles, and save them
def main(input_file, output_file):
    # Load data
    df = pd.read_excel(input_file)

    df = df.iloc[276:551]  # Adjust index as 0-based for Python (row 276 to 550)

    texts = df.iloc[:, 0].tolist()  # Assuming texts are in the first column

    # Extract the first 50 words as prompts
    prompts = get_first_50_words(texts)

    # Generate articles
    articles = generate_articles(generator, prompts)

    # Save generated articles to a new DataFrame and then to Excel
    articles_df = pd.DataFrame(articles, columns=['Prompt', 'Generated Article'])
    articles_df.to_excel(output_file, index=False)
    print(f"Generated articles saved to {output_file}")

# File paths (adjust as necessary)
input_file = '/content/drive/My Drive/ML Project data/train_essays_modified.xlsx'
output_file = '/content/drive/My Drive/ML Project data/output_file_GPT-2(O2).xlsx'

if __name__ == "__main__":
    main(input_file, output_file)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Generating articles for batch starting with prompt: Dear Senate, It's official, The Electoral College ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear Senate, It's official, The Electoral College
# Article generated from prompt: Cars, they help us get from point A to B in a shor
# Article generated from prompt: The world has become a plastic bag of pollution, s
# Article generated from prompt: The electoral college should be abolished and the
# Article generated from prompt: Cars are not something that have to be used everyd
# Article generated from prompt: Since our very first President George Washington o
# Article generated from prompt: The use of cars today in our modern world is crazy
# Article generated from prompt: Dear, Senator I'am a conserend voter that believes
# Article generated from prompt: Dear Senator, The process of voting through the El
# Article generated from prompt: I have an opinion that I know others will agree wi
# Article generated from prompt: Many countries are pushing towards less cars, ulti
# Article generated from prompt: You hear it all, throughout breaking news to prote
# Article generated from prompt: The electoral college, despite being established b
# Article generated from prompt: Could you imagine your life without a car? It seem
# Article generated from prompt: Automobiles have been used as the average use of t
# Article generated from prompt: Recent trends are showing that the average person
# Article generated from prompt: Global warming is a huge concern, and most of the
# Article generated from prompt: Dear State Seiator, Im just a regular voter arguii
# Article generated from prompt: transportation has been a key part of many societi
# Article generated from prompt: Senator of Florida, im writing you today to addres
# Generating articles for batch starting with prompt: Fellow Citizens, there are many reasons why limiti...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Fellow Citizens, there are many reasons why limiti
# Article generated from prompt: Last year in 2014, the earth had the warmest tempe
# Article generated from prompt: World war II was the start of development centerin
# Article generated from prompt: Many cities are now switching to become "car free"
# Article generated from prompt: Many people around the world drive vehicles to get
# Article generated from prompt: Dear Florida Senator, As a citizen, i believe that
# Article generated from prompt: Between years 2001 and 2009 driving by young peopl
# Article generated from prompt: Everyone nowadays is so used to driving a car here
# Article generated from prompt: In our world, air pollution is a huge problem. Mos
# Article generated from prompt: There are many advantages of limiting your car usa
# Article generated from prompt: All arround the world countries are making an effo
# Article generated from prompt: From the crammed streets of New York City, to the
# Article generated from prompt: To my fellow citizens all across the world I think
# Article generated from prompt: Now a days you see everyone with cars driving to p
# Article generated from prompt: Many people believe that it is necessary to use a
# Article generated from prompt: Dear,State Senator The election of our country's l
# Article generated from prompt: Of course, many people from all over the world are
# Article generated from prompt: Car use all over the world has tried to be reduced
# Article generated from prompt: Dear Florida State Senator, Every 4 years, many pe
# Article generated from prompt: Dear State Senator, This is a letter to you to dis
# Generating articles for batch starting with prompt: Dear or or Ms Senator, Presient Richard Nixon, and...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear or or Ms Senator, Presient Richard Nixon, and
# Article generated from prompt: When it comei to automobilei they can provide ui w
# Article generated from prompt: The presidenit is our leader. And you don'it wanit
# Article generated from prompt: The Electoral College is a process in which electo
# Article generated from prompt: Many problems that our world is facing right now a
# Article generated from prompt: To whomever it may concern, The process of the Ele
# Article generated from prompt: Dear state senator, There has been an ongoing conf
# Article generated from prompt: In deciding on who will be in charge of our nation
# Article generated from prompt: Fellow citizens cars are dying out. Every year mor
# Article generated from prompt: Hello, I am writing to you about the Electoral Col
# Article generated from prompt: As the global concern for the environment increase
# Article generated from prompt: Car usage can effect the air causing smog and incr
# Article generated from prompt: Do you ever wonder why the world is becoming so mu
# Article generated from prompt: In our world today many people use motor vehicles
# Article generated from prompt: Dear Mr. Senator, It has come to my, as well as ma
# Article generated from prompt: Dear State Senator, The Electoral College is a sys
# Article generated from prompt: Car emissions are very deadly and dangerous. They
# Article generated from prompt: Around the world, cars are the main use of transpo
# Article generated from prompt: To State Senator, As many believe, the nation of t
# Article generated from prompt: Work. School. Party. No matter what you have on yo
# Generating articles for batch starting with prompt: Dear State Senator, What do you think of the Elect...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear State Senator, What do you think of the Elect
# Article generated from prompt: In every presidential election, thousands of ameri
# Article generated from prompt: More people today are driving less and using publi
# Article generated from prompt: In this day and age, car ownership is extremely co
# Article generated from prompt: Dear senatoor of Florida. I am here tooday too toe
# Article generated from prompt: Dear senator, The electoral process is extremely u
# Article generated from prompt: Most likely im in a car every day of my life and t
# Article generated from prompt: The Electoral College is a system which was establ
# Article generated from prompt: I think that the electoral votes should not decide
# Article generated from prompt: There is a lot of discussion whether or not to kee
# Article generated from prompt: There are many advantages of limiting car usage. D
# Article generated from prompt: The process of chosing a president should be chang
# Article generated from prompt: State Senator, If the slogan of our nation is "We
# Article generated from prompt: The advantages of limiting car use can help the en
# Article generated from prompt: "In the United States, the Environmental Protectio
# Article generated from prompt: Dear Florida Senator, The ongoing debate of whethe
# Article generated from prompt: Should we keep the Electoral College or changing t
# Article generated from prompt: "When I had a car, I was always tense," Heidrun Wa
# Article generated from prompt: In the modern world, it's uncommon to see someone
# Article generated from prompt: To all my fellow citizens, I must tell you about a
# Generating articles for batch starting with prompt: Many people feel that the president plays a very i...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Many people feel that the president plays a very i
# Article generated from prompt: I believe that there are many advantages when it c
# Article generated from prompt: Having an electoral college is a controversial top
# Article generated from prompt: A new trend is starting to spread rapidly across A
# Article generated from prompt: Numerous amount of people would love to experience
# Article generated from prompt: Dear state senator, I strongly believe that we sho
# Article generated from prompt: The Electoral College is a cruel, pointless proces
# Article generated from prompt: We can all be a superhero. Saving the world from s
# Article generated from prompt: A huge percentage of Americans want the Electoral
# Article generated from prompt: The extensive use of car transportation is setting
# Article generated from prompt: Dear Senator, Have you ever thought about changing
# Article generated from prompt: For decades, society has put a major emphasis on t
# Article generated from prompt: Limiting car usage can affect our environment in s
# Article generated from prompt: We should keep with changing to election by popula
# Article generated from prompt: Who needs a car anyway? that is what causes pollut
# Article generated from prompt: Americans throughout the country believe that the
# Article generated from prompt: Dear state senator, There has been some controvers
# Article generated from prompt: Dear, Senator There are many ways in keeping the c
# Article generated from prompt: THere has been quite a lot of recent talk of which
# Article generated from prompt: America's government was inspired by the Athenian
# Generating articles for batch starting with prompt: There are many things that could go wrong with the...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: There are many things that could go wrong with the
# Article generated from prompt: Dear senator, I agree with keeping the Electoral C
# Article generated from prompt: Dear Mr. Senator, Over the course of American hist
# Article generated from prompt: Vroom! Vroom! Is the familiar and common sound hea
# Article generated from prompt: Taking a deep breath in a city filled with cars an
# Article generated from prompt: "All of our development since World War II has bee
# Article generated from prompt: I believe that the electoral college should not be
# Article generated from prompt: The electoral college is a very controversial topi
# Article generated from prompt: There are a lot of advantages of limiting car usag
# Article generated from prompt: The Electoral College was established in the Const
# Article generated from prompt: Cars have become an every day part of our lives, n
# Article generated from prompt: Over the past years massive car usage has increase
# Article generated from prompt: Limiting car usage would have many advantages to t
# Article generated from prompt: Since the 1900's cars have been an integral part o
# Article generated from prompt: Many people in the world today are quite desperate
# Article generated from prompt: Some might thing cars are essential to life, but o
# Article generated from prompt: To keep the Electoral College, or to switch to ele
# Article generated from prompt: Limiting car usage will have many advantages. Not
# Article generated from prompt: The Electoral College is a system of appointing el
# Article generated from prompt: We need to keep the Electoral College because it k
# Generating articles for batch starting with prompt: In the United States, democracy is advertised as a...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: In the United States, democracy is advertised as a
# Article generated from prompt: Dear State senator, A lot of chatter about weather
# Article generated from prompt: Limiting your car use could be a great way to enjo
# Article generated from prompt: There are many advantages to limiting car usage. I
# Article generated from prompt: Dear Senaitor, I feel ithait ithe elecitoral colle
# Article generated from prompt: When you think about limiting car usage you might
# Article generated from prompt: Richard Nixon, Jimmy Carter, and Bob Dole are some
# Article generated from prompt: Dear every state senator of the United States of A
# Article generated from prompt: Imagine the world in the future, completely full a
# Article generated from prompt: Turning 16 is one of the best times of your life b
# Article generated from prompt: Many people do not rely on their cars to take them
# Article generated from prompt: Many people question why we use the Electoral Coll
# Article generated from prompt: Many people dream of buying a new car by the time
# Article generated from prompt: The Electoral College is a process begun a long ti
# Article generated from prompt: Cars have become apart of the everyday life of the
# Article generated from prompt: Dear state senator, Many people believe that the E
# Article generated from prompt: I think that keeping electoral college would be a
# Article generated from prompt: Beep! Beep! Everyday people around the world drive
# Article generated from prompt: My fellow citizens, allow me to make an urgent ann
# Article generated from prompt: Every 4 years, the first Tuesday in November. When
# Generating articles for batch starting with prompt: To the senator of the state of Florida you have as...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: To the senator of the state of Florida you have as
# Article generated from prompt: To start, people use cars everyday to go to work,
# Article generated from prompt: Going place to place in a car is surely the fastes
# Article generated from prompt: In the past, the act of driving was a mandatory ab
# Article generated from prompt: I believe that the electoral college is an outdate
# Article generated from prompt: Dear Mr. Senate, I believe that we should change t
# Article generated from prompt: I believe that my state senator should remove the
# Article generated from prompt: I think the Electoral College should stay, because
# Article generated from prompt: Their are so many advantages of limiting car usage
# Article generated from prompt: Decreasing car usage would serve as a benefit to o
# Article generated from prompt: Driving cars may seem like the best way to get fro
# Article generated from prompt: Electoral college... what a compromise! the electo
# Article generated from prompt: Have you ever seen a smog cloud before? Or even be
# Article generated from prompt: Presidential elections provides the United States
# Article generated from prompt: Dear or. Senator, I believe that America should ke
# Article generated from prompt: People use them to commute around various location
# Article generated from prompt: In today's world, many of us see cars as a necessa
# Article generated from prompt: The idea of a carfree life has become more appeali
# Article generated from prompt: there are many thing in life people want and need
# Article generated from prompt: Dear Mr. Senator, We, the people of Florida are co
# Generating articles for batch starting with prompt: Have you ever wondered what it would be like to li...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Have you ever wondered what it would be like to li
# Article generated from prompt: There are many advantages of limiting car usage. U
# Article generated from prompt: Driving is one of America's favorite things to do,
# Article generated from prompt: Presidenas, ahey are ahe mosa powerful people in a
# Article generated from prompt: I have never liked Government intervention on deci
# Article generated from prompt: There has been a lot of dispute about the electora
# Article generated from prompt: Everyone today believes that having a car is the b
# Article generated from prompt: I agree that changing to election by popular vote
# Article generated from prompt: What would living in a world without cars be like?
# Article generated from prompt: There can be many advantages and disadvantages to
# Article generated from prompt: Families all over the world use cars on a daily ba
# Article generated from prompt: There are many advantages of limiting car usage. I
# Article generated from prompt: A time without cars would be a very interesting id
# Article generated from prompt: Dear State Senator, Even though you're most likely
# Article generated from prompt: Dear, State senator Voting is a public thing that
# Article generated from prompt: There are many ways a person can get from one plac
# Article generated from prompt: The Electoral College is a method of voting for Pr
# Article generated from prompt: Even though you may believe that keeping the elect
# Article generated from prompt: Dear State senator, The Electoral college is a pro
# Article generated from prompt: Dear Senator of Florida, I believe the electoral c
# Generating articles for batch starting with prompt: Have you ever thought about what the world would d...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Have you ever thought about what the world would d
# Article generated from prompt: There are several advantages in limiting car usage
# Article generated from prompt: We run our elections by a process called Electoral
# Article generated from prompt: The electoral collage should be disbanded. Not onl
# Article generated from prompt: Is driving a car really that crucial? Do people re
# Article generated from prompt: There are a lot advantages and disadvantages of li
# Article generated from prompt: Dear Senator, We the people, of the United States
# Article generated from prompt: America's great past time might now be just that,
# Article generated from prompt: Driving Everyones dreams when there're just hittin
# Article generated from prompt: Cars are one of thee most common theings in most c
# Article generated from prompt: Limiting car usage has great advantages wether you
# Article generated from prompt: In the past years the car industry has ruled over
# Article generated from prompt: Cars our main source for travel, what we depend on
# Article generated from prompt: The electoral college is a time worn system. Some
# Article generated from prompt: Highways, roads, streets they are everywhere. No m
# Article generated from prompt: When were voting for president were not technicall
# Article generated from prompt: The Electoral College is a easy, yet hard way of a
# Article generated from prompt: Driving can be a huge hassle. Having to spend mone
# Article generated from prompt: There are different advantages that come with limi
# Article generated from prompt: Dear state senator, It is highly unlikely that you
# Generating articles for batch starting with prompt: We should keep the Electoral College for the votin...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: We should keep the Electoral College for the votin
# Article generated from prompt: The electoral college is a process where electors
# Article generated from prompt: Dear Senator, We should abolish the electoral coll
# Article generated from prompt: Dear Florida Senator, I believe that we should not
# Article generated from prompt: How much money do you think you would you save fro
# Article generated from prompt: Dear senator, My associates and I, have thought lo
# Article generated from prompt: "Congestionwas down 60% in the capital of france a
# Article generated from prompt: I think that they should not change the Electoral
# Article generated from prompt: "When I had a car I was always tense. I'm much hap
# Article generated from prompt: Cars have been around for many years and generatio
# Article generated from prompt: Cars have been used for a very long time now and a
# Article generated from prompt: Dear State Senator, My name is PROPER_NAME and i a
# Article generated from prompt: Pretty much all working adults and teenagers own o
# Article generated from prompt: With all this talk about greenhouse gasses, you th
# Article generated from prompt: Presidential election is held every after four yea
# Article generated from prompt: A life without Cars. A life without cars would be
# Article generated from prompt: Over the past few decades, talk regarding car poll
# Article generated from prompt: I think limiting car usage is a great idea for ame
# Article generated from prompt: In the United States we have been voting for presi
# Article generated from prompt: Dear Senator, I believe that people like Richard N
# Generating articles for batch starting with prompt: In the US many people use different methods to get...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: In the US many people use different methods to get
# Article generated from prompt: Many cities around the world have already learned
# Article generated from prompt: I believe that we, the people, should elect our pr
# Article generated from prompt: State senator I ask that you favor the idea of kee
# Article generated from prompt: The Electoral College should get changed to electi
# Article generated from prompt: Dear Florida State Senator, I do not believe that
# Article generated from prompt: Our world has became a world that revolves around
# Article generated from prompt: As time progresses, more and more young people are
# Article generated from prompt: Limiting the usage of cars has a variety of advant
# Article generated from prompt: Many people in today's world depend on cars to get
# Article generated from prompt: The culture of the car has been coming to an end.
# Article generated from prompt: Dear State Senator, The Electoral College has a ne
# Article generated from prompt: Today, automobiles are responsible for 12 percent
# Article generated from prompt: Why is is beneficial to have limited car usage? Th
# Article generated from prompt: Cars have always been known for their efficiency,
# Article generated from prompt: The " " seems to be a very aggravating phrase for
# Article generated from prompt: "All of our development since World War II has bee
# Article generated from prompt: Cars are a major aspect of transportation in the t
# Article generated from prompt: What's the first thing you think about when you se
# Article generated from prompt: Almost everyone owns a car because people are trav
# Generating articles for batch starting with prompt: Many people across the country would believe that ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Many people across the country would believe that
# Article generated from prompt: Citizens of the U.S. have been voting for their pr
# Article generated from prompt: When you think of the USA the first word that you
# Article generated from prompt: "Carfree" Many drivers around the world are decidi
# Article generated from prompt: Dear me. Senator, Today I am asking for your favor
# Article generated from prompt: The Electoral College has been around since the Co
# Article generated from prompt: For the vote for the president of the United State
# Article generated from prompt: Limiting the usage of cars will bring a lot of adv
# Article generated from prompt: Cars nowadays are a big part of our lifes, they ta
# Article generated from prompt: The automobile is one of mankind greatest innovati
# Article generated from prompt: Being in control of your country is exactly what e
# Article generated from prompt: The United States of America has come a long with
# Article generated from prompt: From a sunday drive to a cross country road trip,
# Article generated from prompt: The advantages of limiting car usage can be a grea
# Article generated from prompt: When people hear the word transportation, the firs
# Article generated from prompt: "America for the people, by the people". Dear sena
# Article generated from prompt: Limiting car usage can be beneficial in many ways.
# Article generated from prompt: The Electoral College has made everything easier o
# Article generated from prompt: Voting, one of the most American things I can thin
# Article generated from prompt: How could we get the reduction of Greenhouse Gas?
# Generating articles for batch starting with prompt: Dear state senator, Election day is held every fou...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear state senator, Election day is held every fou
# Article generated from prompt: For years I've heard that voting time is the choic
# Article generated from prompt: The Electoral college is a process in which the el
# Article generated from prompt: Since the industrial revolution the demand for car
# Article generated from prompt: Mustangs, Mercedes, Hummers , and the "Punch buggy
# Article generated from prompt: As stated in the article, the Electoral College pr
# Article generated from prompt: Dear, Senator I think the president should be elec
# Article generated from prompt: All around the world, people are using gasgusling
# Article generated from prompt: Over the years the amount of cars that have been m
# Article generated from prompt: Driving a car has its ups and downs to life. It pr
# Article generated from prompt: In retrospect, people use to be able to live a hap
# Article generated from prompt: For most people it is more common to get from plac
# Article generated from prompt: They should change to election by popular vote. Th
# Article generated from prompt: The electoral college is a process that supposedly
# Article generated from prompt: December 18, 2014 Dear State Senator, Changing to
# Generated articles saved to /content/drive/My Drive/ML Project data/output_file_GPT-2(O2).xlsx
