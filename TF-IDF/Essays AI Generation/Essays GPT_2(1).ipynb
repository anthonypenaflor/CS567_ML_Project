# %%
pip install transformers pandas openpyxl
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
from google.colab import drive
import pandas as pd
from transformers import pipeline

# Mount Google Drive
drive.mount('/content/drive')

# Function to set up the generator pipeline with a specified model
def setup_generator(model_name="gpt2"):  # Using GPT-2 for demonstration
    generator = pipeline('text-generation', model=model_name)
    return generator

# Set up text generation model
generator = setup_generator()
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# For the original train data

# Function to generate text based on prompts, with better error handling
def generate_articles(generator, prompts, max_length=1000):
    articles = []
    batch_size = 20  # Adjust based on your testing and system capabilities
    for i in range(0, len(prompts), batch_size):
        batch_prompts = prompts[i:i + batch_size]
        print(f"Generating articles for batch starting with prompt: {batch_prompts[0][:50]}...")
        generated_texts = generator(batch_prompts, max_length=max_length, num_return_sequences=1)
        for index, generated in enumerate(generated_texts):
            if isinstance(generated, dict):
                articles.append((batch_prompts[index], generated['generated_text']))
                print(f"Article generated from prompt: {generated['generated_text'][:50]}")
            else:
                for item in generated:
                    articles.append((batch_prompts[index], item['generated_text']))
                    print(f"Article generated from prompt: {item['generated_text'][:50]}")
    return articles

# Function to extract the first 50 words
def get_first_50_words(texts):
    prompts = []
    for text in texts:
        words = text.split()[:50]  # Split the text and take the first 50 words
        prompt = ' '.join(words)  # Join the words back into a single string
        prompts.append(prompt)
    return prompts

# Main function to load data, generate articles, and save them
def main(input_file, output_file):
    # Load data
    df = pd.read_excel(input_file)

    # Limit to the first 276 rows (excluding the header), process rows 2 to 276
    df = df.iloc[0:276]  # Adjust index as 0-based for Python (row 2 to 276)

    texts = df.iloc[:, 0].tolist()  # Assuming texts are in the first column

    # Extract the first 50 words as prompts
    prompts = get_first_50_words(texts)

    # Generate articles
    articles = generate_articles(generator, prompts)

    # Save generated articles to a new DataFrame and then to Excel
    articles_df = pd.DataFrame(articles, columns=['Prompt', 'Generated Article'])
    articles_df.to_excel(output_file, index=False)
    print(f"Generated articles saved to {output_file}")

# File paths (adjust as necessary)
input_file = '/content/drive/My Drive/ML Project data/train_essays_modified.xlsx'
output_file = '/content/drive/My Drive/ML Project data/output_file_GPT-2(O1).xlsx'

if __name__ == "__main__":
    main(input_file, output_file)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating articles for batch starting with prompt: Cars. Cars have been around since they became famo...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Cars. Cars have been around since they became famo
# Article generated from prompt: Transportation is a large necessity in most countr
# Article generated from prompt: "America's love affair with it's vehicles seems to
# Article generated from prompt: How often do you ride in a car? Do you drive a one
# Article generated from prompt: Cars are a wonderful thing. They are perhaps one o
# Article generated from prompt: The electrol college system is an unfair system, p
# Article generated from prompt: Dear state senator, It is the utmost respect that
# Article generated from prompt: Fellow citizens, cars have become a major role in
# Article generated from prompt: "It's official: The electoral college is unfair, o
# Article generated from prompt: The Electoral College has been kept for centuries,
# Article generated from prompt: Dear senator, Retain the Electoral College. The El
# Article generated from prompt: "When I had a car I was always tense. I'm much hap
# Article generated from prompt: Voting for a president is one of the most importan
# Article generated from prompt: dear senator, I have come to a conclusion on how I
# Article generated from prompt: Everyone wants to go to the park with their childr
# Article generated from prompt: There are many advantages to limiting car usage in
# Article generated from prompt: dear state senator, i believe that we should aboli
# Article generated from prompt: Transportation has become one of the largest emiss
# Article generated from prompt: We live in a world where the only way to get from
# Article generated from prompt: The long list of benefits that comes from limited
# Generating articles for batch starting with prompt: The system of the Electoral College is a widely ar...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: The system of the Electoral College is a widely ar
# Article generated from prompt: Dear Senator, Many people might agree theat we sho
# Article generated from prompt: In the old world, people didn have car's, they did
# Article generated from prompt: . The Electoral College is a very controversial to
# Article generated from prompt: Dear Florida State Senator, Although many could ar
# Article generated from prompt: Thousands of people around the world use cars. It'
# Article generated from prompt: Although numerous amounts of people want to banish
# Article generated from prompt: There are many different things that you could do
# Article generated from prompt: Dear Senator, The Electoral College as controversi
# Article generated from prompt: In the generation we are living in today cars are
# Article generated from prompt: We should keep the Electoral College for a number
# Article generated from prompt: I beam, flashing a smile towards the camera of my
# Article generated from prompt: Voting. Voting is a pretty big deal that only come
# Article generated from prompt: The Electoral College is a very useful and easy wa
# Article generated from prompt: "It's official: The electoral college is unfair, o
# Article generated from prompt: In the following ideas and information passage set
# Article generated from prompt: I was very excited about my first trip to the West
# Article generated from prompt: Do you know why the earth has air pollution ? they
# Article generated from prompt: To access what one needs in the world today, many
# Article generated from prompt: Though I have not been alive to see most of it, I
# Generating articles for batch starting with prompt: By limiting car usage you would be making it a hea...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: By limiting car usage you would be making it a hea
# Article generated from prompt: Getting rid of the electoral college would be illo
# Article generated from prompt: The anachronism that is the electoral college is a
# Article generated from prompt: The United States has been known for life, liberty
# Article generated from prompt: Have you ever wondered what will happen if we keep
# Article generated from prompt: "All of our development since world war II has bee
# Article generated from prompt: In order to dramatically reduce greenhouse gases,
# Article generated from prompt: There are several advantages when you limit car us
# Article generated from prompt: Within countries around the world people are comin
# Article generated from prompt: Many people are in belief of evaporating the idea
# Article generated from prompt: Since remotely times, the manhad look for some way
# Article generated from prompt: Dear fellow citizens of America it has come to my
# Article generated from prompt: Reducing the usage of cars in today's world could
# Article generated from prompt: To be fair,both the electoral college and a aoaula
# Article generated from prompt: Dear Rick Scott, Controversial. This is the word t
# Article generated from prompt: Many people throughout the world, would agree that
# Article generated from prompt: Are we using cars too much? In Source 2 : Paris ba
# Article generated from prompt: They come in red, blue, green, black, and white. T
# Article generated from prompt: Why are the streets always so jammed!? Everyone as
# Article generated from prompt: For a long time now we have been fighting against
# Generating articles for batch starting with prompt: America is the country of the people, the people a...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: America is the country of the people, the people a
# Article generated from prompt: There are a lot of things that develop and hold a
# Article generated from prompt: Dear State Senator, I think that we should change
# Article generated from prompt: Dear State Senator, most people in theis country m
# Article generated from prompt: The Electoral College? Some would say this way of
# Article generated from prompt: Dear State Senator, I am agreeing in favor of keep
# Article generated from prompt: The Electoral College is best described as outdate
# Article generated from prompt: Car usage all over the world has reduced and been
# Article generated from prompt: Society has made the car industry accelerate rapid
# Article generated from prompt: The majority of Americans have the luxury of ownin
# Article generated from prompt: There are many advantages to limiting car usage an
# Article generated from prompt: The wheel was the first step that took society int
# Article generated from prompt: While many may argue for it, the Electoral College
# Article generated from prompt: By limiting car usage, research has shown there is
# Article generated from prompt: Whether we have our license or not, we can all rel
# Article generated from prompt: In the westminster system, the head of state and o
# Article generated from prompt: Dear Senator, The electoral college was a perfect
# Article generated from prompt: Cars are a luxury, but others take them for grante
# Article generated from prompt: Think about how many times a week we get in a car
# Article generated from prompt: Dear Florida senator, I'm a young student, and no
# Generating articles for batch starting with prompt: Dear state senator, There should be a change in th...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear state senator, There should be a change in th
# Article generated from prompt: The automobile is a production commonly used by in
# Article generated from prompt: Dear Senator, I would like to bring to your attent
# Article generated from prompt: Dear Senator, I along with many other citizens hav
# Article generated from prompt: Cars have been the main use for transportation fro
# Article generated from prompt: The Electoral College is a controversial topic in
# Article generated from prompt: Dear Senator, The debate regarding the necessity o
# Article generated from prompt: I believe that we should get rid of Electoral Coll
# Article generated from prompt: To the State Senate, Addressing my ultimate opinio
# Article generated from prompt: Nearly everyone in the United States has a car, if
# Article generated from prompt: Ever since their creation, cars have been the main
# Article generated from prompt: Imagine a life without cars. All those paved roads
# Article generated from prompt: Many countries and places are starting to reduce t
# Article generated from prompt: Dear senator, the Electoral College has always bee
# Article generated from prompt: The Electoral College is an outdated system of vot
# Article generated from prompt: In the world we live in today, cars are used by pe
# Article generated from prompt: When electing the president of the United States,
# Article generated from prompt: Dear Senator, Concerning the topic of the merits a
# Article generated from prompt: Sometimes you don't need a car to go some place, y
# Article generated from prompt: Car alarms, car horns, and engines are basically t
# Generating articles for batch starting with prompt: Dear Senator, I am a student writing to you that w...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear Senator, I am a student writing to you that w
# Article generated from prompt: The electoral college is a bad thing because voter
# Article generated from prompt: In the recent years the state of the country has b
# Article generated from prompt: Dear Senator, The Electoral College was created ma
# Article generated from prompt: As our atmosphere constantly changes, so do our ha
# Article generated from prompt: Dear Mr. State Senator, I am writing this letter t
# Article generated from prompt: There are many advantages to limiting car usage. I
# Article generated from prompt: In the United States of America, and all over the
# Article generated from prompt: Dear Senator Adams, Voting for a president is not
# Article generated from prompt: Dear Mr. Senator, As you are most likely aware, th
# Article generated from prompt: "The Electoral College is a process, not a place.
# Article generated from prompt: Dear State Senator, I believe that something shoul
# Article generated from prompt: As one of the people living in Florida I am honor
# Article generated from prompt: The electoral college is an institution that has a
# Article generated from prompt: "With less cars we have less accidents and less pr
# Article generated from prompt: Dear Senator, The topic of the Electoral college i
# Article generated from prompt: " What's wrong with the Electoral College?" To be
# Article generated from prompt: Imagine getting off work on a Friday at five o'clo
# Article generated from prompt: Everyday a great many people drive their cars to c
# Article generated from prompt: In a society where things are always changing and
# Generating articles for batch starting with prompt: All around the world, cars have influence our live...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: All around the world, cars have influence our live
# Article generated from prompt: Do you want to elect the president? The electoral
# Article generated from prompt: As crazy as living without a car sounds, more and
# Article generated from prompt: Many people agree in abolishing the Electoral Coll
# Article generated from prompt: Every day people wake up, get ready, and go to wor
# Article generated from prompt: The electoral college is an unfair and outdated sy
# Article generated from prompt: The Electoral College is America's current method
# Article generated from prompt: "I'm much happier this way," What caused someone t
# Article generated from prompt: The usage of motor vehicles has been on a steady d
# Article generated from prompt: The Electoral college is a process where electors
# Article generated from prompt: At first, the idea of not using a car may seem lik
# Article generated from prompt: We use cars every day, but have we ever actually s
# Article generated from prompt: cars are everywhere these days, and they are commo
# Article generated from prompt: Some people like to drive while others don't and s
# Article generated from prompt: Having a limit on car usage has many advantages to
# Article generated from prompt: It's the Tuesday after the first Monday in Novembe
# Article generated from prompt: Why should we limit our uses on car usage, some pe
# Article generated from prompt: Cars thery're every where, and people use cars to
# Article generated from prompt: The role a car plays in the life of an individual
# Article generated from prompt: Some of the advantages of limiting car usage is de
# Generating articles for batch starting with prompt: Many citizens in the United States rely on cars as...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Many citizens in the United States rely on cars as
# Article generated from prompt: Life without cars may seem like a distant dream, b
# Article generated from prompt: In the intense debate concerning the validity of t
# Article generated from prompt: Life has revolved around driving since the termina
# Article generated from prompt: What is the electoral college? The electoral colle
# Article generated from prompt: To the Senator of Florida, "The founding fathers e
# Article generated from prompt: One uses a car to go to thee store, pick someone u
# Article generated from prompt: The electoral college ii iomething that hai been l
# Article generated from prompt: Many people carry out their daily life routine via
# Article generated from prompt: Dear state senator, I urge you to vote in favor of
# Article generated from prompt: Dear Senator, Good day, I am writing this letter t
# Article generated from prompt: There are many fellow citizens in the world that h
# Article generated from prompt: The Electoral College is used in the United States
# Article generated from prompt: The reduction or limited usage of cars impacts the
# Article generated from prompt: The automobile was made a long time ago to help us
# Article generated from prompt: The Electoral College has been around for many yea
# Article generated from prompt: 12% of all green house gas in Europe is from is fr
# Article generated from prompt: Dear senator, I wanted to write you this letter to
# Article generated from prompt: Limiting the use of cars seems like a crazy idea b
# Article generated from prompt: Dear Senator, The Presidential election is one of
# Generating articles for batch starting with prompt: We live in a world where we rely on cars to get us...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: We live in a world where we rely on cars to get us
# Article generated from prompt: Cars. Trucks. motorcycles. All these forms of tran
# Article generated from prompt: Dear Mr. Florida State Senator, My name is PROPER_
# Article generated from prompt: Dear state senator, Hello my name is PROPER_NAME a
# Article generated from prompt: All throughout the world, experiments are taking p
# Article generated from prompt: It is often said that "change is good." This sayin
# Article generated from prompt: To begin with, the Electoral College should be kep
# Article generated from prompt: Having "electors" vote for us from the electoral c
# Article generated from prompt: Dear Senator, I know that you have many issues to
# Article generated from prompt: The Electoral College basically serves as a filter
# Article generated from prompt: Cars are an essential part of life they get us fro
# Article generated from prompt: "The Electoral College process consists of the sel
# Article generated from prompt: Dear State Senator, I propose that we change the e
# Article generated from prompt: While owning a car may seem like the most importan
# Article generated from prompt: The electoral college should be abolished because
# Article generated from prompt: When limiting car usage the first thing that most
# Article generated from prompt: Dear State Senator, I believe that the Electoral C
# Article generated from prompt: Dear my Senator, whats the point in voting if our
# Article generated from prompt: Cars are a very, very common mode of transportatio
# Article generated from prompt: You get pearly on November 6, 2012 ready to vote,
# Generating articles for batch starting with prompt: Dear Mr. Senator, My names is PROPER_NAME. I am 14...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear Mr. Senator, My names is PROPER_NAME. I am 14
# Article generated from prompt: Dear saaae senaaor, My leaaer is in regards ao cha
# Article generated from prompt: Voting for president should be fair and democratic
# Article generated from prompt: Bycicles. Walking. Public buses. All three are alt
# Article generated from prompt: Changing our ways on how we use cars for the bette
# Article generated from prompt: Dear me. Senator, I am fed up with the electoral c
# Article generated from prompt: There are many advantages to limiting car usage. T
# Article generated from prompt: A Electoral College is a meeting of thee electors
# Article generated from prompt: Every four years since the founding of the United
# Article generated from prompt: Imagine a world without garages, stations, or park
# Article generated from prompt: People in America vote for a candidate running for
# Article generated from prompt: or. Senator, I think that the Electoral College is
# Article generated from prompt: Dear Senator, There has been some recent heat on t
# Article generated from prompt: When hearing about the Electoral College, most peo
# Article generated from prompt: I believe that the electoral college should be tak
# Article generated from prompt: The electoral college, a mistake? Many Americans a
# Article generated from prompt: Greetings Mr. State Senator, Looking over the Elec
# Article generated from prompt: When you turn sixteen, you're filled with anticipa
# Article generated from prompt: America's love of cars may soon be spiraling down.
# Article generated from prompt: Cars are starting to become more and more expensiv
# Generating articles for batch starting with prompt: Limiting car usage could greatly benefit the lifes...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Limiting car usage could greatly benefit the lifes
# Article generated from prompt: The using of cars has caused much of the worlds gr
# Article generated from prompt: Driving is a way of getting around quicker and to
# Article generated from prompt: dear state senator, As you know America is very di
# Article generated from prompt: Cars have been used and started to rise since Worl
# Article generated from prompt: Dear Senator, I am writing you to explain why the
# Article generated from prompt: Cars have been a great way of transportation that
# Article generated from prompt: The Electoral College has been a part of America s
# Article generated from prompt: Since our beautiful country was born we've always
# Article generated from prompt: Dear Senator, I heartily agree that we the people
# Article generated from prompt: The Electoral College, good or bad? Many may feel
# Article generated from prompt: I have been burdened with the fact that our nation
# Article generated from prompt: It hao nearly been two centurieo oince our country
# Article generated from prompt: Limited car usage has plenty of advantages. A few
# Article generated from prompt: Hello, my name is PROPER_NAME, a freshman at SCHOO
# Article generated from prompt: Dear Florida state senator, I argue in favor of ke
# Article generated from prompt: Cars are useful machines that get you around. But
# Article generated from prompt: Growing up in the more modern times I see many thi
# Article generated from prompt: "My fellow americans," a phrase said by many impor
# Article generated from prompt: A major form of transportation that has been aroun
# Generating articles for batch starting with prompt: In a world of large cities and distant suburbs, tr...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: In a world of large cities and distant suburbs, tr
# Article generated from prompt: Cars are becoming a dying trend all over the world
# Article generated from prompt: I profoundly believe that the United States should
# Article generated from prompt: What would you do if you got written a ticket by a
# Article generated from prompt: In order to inform the fellow citizens about the a
# Article generated from prompt: Do you ever wonder how it would be if we lived in
# Article generated from prompt: Cars have become a part of our modern day culture
# Article generated from prompt: Dear State Senator, I believe that we should chang
# Article generated from prompt: Theres so many roads in the world but traffic stil
# Article generated from prompt: There are different types of cars, small cars, big
# Article generated from prompt: Our social lives now a days practically depend on
# Article generated from prompt: Man conquered its environment with advancements an
# Article generated from prompt: A car is considered by many a nessecity for everyd
# Article generated from prompt: There has beeon a major awareoness of the effects
# Article generated from prompt: Most people rely on vehicles for every day aarons.
# Article generated from prompt: There are many ways of limiting car usage. Some ad
# Article generated from prompt: Dear state senator, I think the voting should be b
# Article generated from prompt: In the newer ages, people were worried about how t
# Article generated from prompt: Fellow citizenis, I would like to talk about the a
# Article generated from prompt: Dear Senator, I know you have a lot of things on y
# Generating articles for batch starting with prompt: Dear state senator, The Electoral College that was...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear state senator, The Electoral College that was
# Article generated from prompt: The electoral College is the way us United State c
# Article generated from prompt: Throughout the years, humans have always had to ge
# Article generated from prompt: Since Henry Ford made the first Model T, people ha
# Article generated from prompt: When you go to vote for the president are you actu
# Article generated from prompt: From riding horses with wagons to, driving cars. t
# Article generated from prompt: Dear senator, The Electoral College is unfair, out
# Article generated from prompt: Dear State Senator, I have realized that there has
# Article generated from prompt: Dear Mr.Mrs. Senator, In light of previous researc
# Article generated from prompt: Dear Senator of Florida, I think changing the elec
# Article generated from prompt: Dear Senator of Florida, I am a 15 year old concer
# Article generated from prompt: Are cars beginning to go out of fashion? Over the
# Article generated from prompt: The process of the electing the president is a top
# Article generated from prompt: January 23rd, 2015 Greetings or. Senator, There is
# Article generated from prompt: Limiting car usage can seem like a far fetched ide
# Article generated from prompt: The effect of cars in our world today has grown tr
# Article generated from prompt: Dear Florida senator, I am writing to you today to
# Article generated from prompt: Dear State Senator, Every four years, the time rol
# Article generated from prompt: Dear State Senator, In my opinion, Im in favor of
# Article generated from prompt: Dear State Senate, The Electoral College is insane
# Generating articles for batch starting with prompt: Every day, thousands of people lose their lives to...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Every day, thousands of people lose their lives to
# Article generated from prompt: Dear state senator, to the people voting is the mo
# Article generated from prompt: As human beings we must care for the earth that wa
# Article generated from prompt: Cars have long been viewed as a common method of t
# Article generated from prompt: By limiting car uses, many great advantages arise.
# Article generated from prompt: Dear Senator of Florida, Though longstanding and "
# Article generated from prompt: The electoral college is pointless, I believe that
# Article generated from prompt: A man is driving in his car recklessly in a hurry
# Article generated from prompt: Their are so many things you can do to help keep t
# Article generated from prompt: "Do voters really control whom their elector picks
# Article generated from prompt: Dear, I believe that the way of voting for a presi
# Article generated from prompt: Thick, foggy air is the future for this planet if
# Article generated from prompt: Dear state senator, The electoral collage system h
# Article generated from prompt: Dear Senator I am not in favor of keeping the Elec
# Article generated from prompt: To maintain driving and caring for a car takes a l
# Article generated from prompt: Dear state senator, We should not decide the presi
# Generated articles saved to /content/drive/My Drive/ML Project data/output_file_GPT-2(O1).xlsx
