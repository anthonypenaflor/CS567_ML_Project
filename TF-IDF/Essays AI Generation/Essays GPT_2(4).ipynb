# %%
pip install transformers pandas openpyxl
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
from google.colab import drive
import pandas as pd
from transformers import pipeline

# Mount Google Drive
drive.mount('/content/drive')

# Function to set up the generator pipeline with a specified model
def setup_generator(model_name="gpt2"):  # Using GPT-2 for demonstration
    generator = pipeline('text-generation', model=model_name)
    return generator

# Set up text generation model
generator = setup_generator()
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# For the original train data

# Function to generate text based on prompts, with better error handling
def generate_articles(generator, prompts, max_length=1000):
    articles = []
    batch_size = 20  # Adjust based on your testing and system capabilities
    for i in range(0, len(prompts), batch_size):
        batch_prompts = prompts[i:i + batch_size]
        print(f"Generating articles for batch starting with prompt: {batch_prompts[0][:50]}...")
        generated_texts = generator(batch_prompts, max_length=max_length, num_return_sequences=1)
        for index, generated in enumerate(generated_texts):
            if isinstance(generated, dict):
                articles.append((batch_prompts[index], generated['generated_text']))
                print(f"Article generated from prompt: {generated['generated_text'][:50]}")
            else:
                for item in generated:
                    articles.append((batch_prompts[index], item['generated_text']))
                    print(f"Article generated from prompt: {item['generated_text'][:50]}")
    return articles

# Function to extract the first 50 words
def get_first_50_words(texts):
    prompts = []
    for text in texts:
        words = text.split()[:50]  # Split the text and take the first 50 words
        prompt = ' '.join(words)  # Join the words back into a single string
        prompts.append(prompt)
    return prompts

# Main function to load data, generate articles, and save them
def main(input_file, output_file):
    # Load data
    df = pd.read_excel(input_file)

    df = df.iloc[826:1101]  # Adjust index as 0-based for Python (row 826 to 1100)

    texts = df.iloc[:, 0].tolist()  # Assuming texts are in the first column

    # Extract the first 50 words as prompts
    prompts = get_first_50_words(texts)

    # Generate articles
    articles = generate_articles(generator, prompts)

    # Save generated articles to a new DataFrame and then to Excel
    articles_df = pd.DataFrame(articles, columns=['Prompt', 'Generated Article'])
    articles_df.to_excel(output_file, index=False)
    print(f"Generated articles saved to {output_file}")

# File paths (adjust as necessary)
input_file = '/content/drive/My Drive/ML Project data/train_essays_modified.xlsx'
output_file = '/content/drive/My Drive/ML Project data/output_file_GPT-2(O4).xlsx'

if __name__ == "__main__":
    main(input_file, output_file)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Generating articles for batch starting with prompt: Do you know what pollution is? Have you ever taken...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Do you know what pollution is? Have you ever taken
# Article generated from prompt: The world is advancing, technologies are being bui
# Article generated from prompt: A decline in the use of motor vehicles would great
# Article generated from prompt: Smog, backed up traffic ways, and stress seem to b
# Article generated from prompt: Millions of people around the world use cars, truc
# Article generated from prompt: The electoral college has many reasons it should s
# Article generated from prompt: Many people in the United States are becoming more
# Article generated from prompt: The whole purpose of democracy is to create a gove
# Article generated from prompt: Vroom, vroom goes the 1998 Chevy Impala next to yo
# Article generated from prompt: Cars, they are used for many purposes including ta
# Article generated from prompt: Dear Florida's state senator, Everyone, whether ol
# Article generated from prompt: Being a person of politics yourself, you of all pe
# Article generated from prompt: Dear State Senator, Many people today have very st
# Article generated from prompt: In the text provided, it discusses the advantages
# Article generated from prompt: To the senator of florida, I believe that the elec
# Article generated from prompt: Dear, Senator Electoral college has been around fo
# Article generated from prompt: People all over the world use cars to drive to wor
# Article generated from prompt: Cars most are used by workers, mothers, and pretty
# Article generated from prompt: Believe it or not there are ways people may be har
# Article generated from prompt: Whether if it's a law in a country, the source of
# Generating articles for batch starting with prompt: Cars are benefits for getting you from point A to ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Cars are benefits for getting you from point A to
# Article generated from prompt: There are so many advantages of limiting car usage
# Article generated from prompt: Ever since cars were invented, they have widely be
# Article generated from prompt: "But America's love affair with its vehicles seems
# Article generated from prompt: Dear Mr. State Senator, I have been a citizen of t
# Article generated from prompt: Cars in this century are being band for multiple r
# Article generated from prompt: There are plenty of advantages of limiting car usa
# Article generated from prompt: The Electoral College is a system that should no l
# Article generated from prompt: The Declaration of Independence granted us the rig
# Article generated from prompt: It seems that almost everyone I know has a car. Ho
# Article generated from prompt: To whome this may concern the electoral college is
# Article generated from prompt: Dear Mr. Senator, I believe that the way our elect
# Article generated from prompt: The Electoral College is a process that should be
# Article generated from prompt: The Electoral College was created with good intent
# Article generated from prompt: Abolishing the Electoral College sounds like an ex
# Article generated from prompt: To whom it may concern, I have recently been enlig
# Article generated from prompt: Many people in todays society tend to travel by ca
# Article generated from prompt: Mr Senator, After being informed of the United Sta
# Article generated from prompt: Dear Senator of Florida, What is the point of peop
# Article generated from prompt: CarFree Cities Humans almost feel the need to own
# Generating articles for batch starting with prompt: "No one cares about the environment." said no one ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: "No one cares about the environment." said no one
# Article generated from prompt: Every four years there is an election. The electio
# Article generated from prompt: "Abolish the electoral college!" is a famous state
# Article generated from prompt: People in today's society practically depend on th
# Article generated from prompt: Cars are usually in most peoples every day lives.
# Article generated from prompt: Transportation by a vehicle like a car is very com
# Article generated from prompt: Uiing cari today ii polauting the air we breath in
# Article generated from prompt: Cars have always been apart of American culture. F
# Article generated from prompt: "Less Cars" "Vrroooom vroom," that is all that peo
# Article generated from prompt: The dispute over keeping the Electoral College or
# Article generated from prompt: I wholeheartedly believe the United States should
# Article generated from prompt: In America, presidents are voted in by the elector
# Article generated from prompt: Dear me.senator, My name is PROPER_NAME. The Elect
# Article generated from prompt: There are many advantages to limiting car usage. T
# Article generated from prompt: Humankind has always been fascinated with the conc
# Article generated from prompt: The Electoral College has been in the Constitution
# Article generated from prompt: The founding father's wanted a good amount of powe
# Article generated from prompt: In the world today you will see cars just about ev
# Article generated from prompt: People use cars everyday, but limiting car usage c
# Article generated from prompt: Dear Senator of Florida, Electoral Colleges are bi
# Generating articles for batch starting with prompt: Cars most people use them for transportation. It's...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Cars most people use them for transportation. It's
# Article generated from prompt: The Electoral College consists of more cons than p
# Article generated from prompt: The Electoral College system is not something Amer
# Article generated from prompt: I argue in favor of keeping the electoral college
# Article generated from prompt: The Electoral College is a process which occurs in
# Article generated from prompt: Dear, state senator The Electoral College should b
# Article generated from prompt: Dear Senator, I want to change to election by popu
# Article generated from prompt: Cars may have some advantages, but the world, woul
# Article generated from prompt: For many years people have been using cars to get
# Article generated from prompt: Limiting car usage has many advantages, from savin
# Article generated from prompt: Goodmorning fellow citizens , i hope you all are h
# Article generated from prompt: Why drive when you can use many other alternatives
# Article generated from prompt: As an American citizen, I am aware that cars are a
# Article generated from prompt: When each person drives a dieseltussling car, it i
# Article generated from prompt: Dear senator, the system we have today used to ele
# Article generated from prompt: Over the course of years new technologies have bee
# Article generated from prompt: Cars are creating an harmful environment with prob
# Article generated from prompt: Dear State Senator of Florida, I believe that we s
# Article generated from prompt: "All of our development since World War ll has bee
# Article generated from prompt: I would like our election to be cast on popular vo
# Generating articles for batch starting with prompt: Dear Mr. Senator, Freedom to vote for authority fi...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear Mr. Senator, Freedom to vote for authority fi
# Article generated from prompt: Most people think that the electoral college is no
# Article generated from prompt: The Electoral College vote draws many emotions. It
# Article generated from prompt: Car usage is very popular in this world we have co
# Article generated from prompt: land of the free, the brave, and millions of proud
# Article generated from prompt: Electoral College is the way American people get t
# Article generated from prompt: Dear Mr. Senator, I am writing you concerning a to
# Article generated from prompt: The Electoral College was a system thought up by p
# Article generated from prompt: Have you ever walked outside and taken a deep brea
# Article generated from prompt: People are finally opening their eyes to the world
# Article generated from prompt: The Electoral College should remaining our countri
# Article generated from prompt: Everyone has at less had one car in there life tim
# Article generated from prompt: Dear State Senator, In this essay I will be explai
# Article generated from prompt: The age of cars has come to a grinding stop. Atlea
# Article generated from prompt: Does athe elecatoral college work? I don'at athink
# Article generated from prompt: Dear Florida state senator, In few words, the Unit
# Article generated from prompt: The people have a right to say what they want to h
# Article generated from prompt: The presidential elections are a huge deal in the
# Article generated from prompt: Car uaage around tohe world ia cauaing an increaae
# Article generated from prompt: I remember thee stories my dad use to tell me abou
# Generating articles for batch starting with prompt: Dear Senator... The electoral college has recently...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear Senator... The electoral college has recently
# Article generated from prompt: Our population is booming and with it, our car ind
# Article generated from prompt: Limiting car usage has many advantages. The most i
# Article generated from prompt: The United States is a democratic country where th
# Article generated from prompt: The Electoral College is not perfect and it may be
# Article generated from prompt: Recently, in many countries around the world, ther
# Article generated from prompt: Many places around the world have been taking char
# Article generated from prompt: Since the invention of the first automobiles, nega
# Article generated from prompt: The advantages of limiting car usage has erupted s
# Article generated from prompt: Personally, I believe that there are many advantag
# Article generated from prompt: The United States of America is constantly referre
# Article generated from prompt: The United States has ways of being civilized, and
# Article generated from prompt: Living in a world covered in dark,suffocating smog
# Article generated from prompt: We all plan to get cars when we get our licenses r
# Article generated from prompt: Who are voters voting for? Whoever they are voting
# Article generated from prompt: Dear Florida Senator, There has been much controve
# Article generated from prompt: Dear State Senator, I am in favor of changing to e
# Article generated from prompt: Now and days, our world has transformed from using
# Article generated from prompt: Dear Senator, I am writing to you to argue in favo
# Article generated from prompt: There is a lot controversy regarding the Electoral
# Generating articles for batch starting with prompt: Dear Senator, The robust political system of the A...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear Senator, The robust political system of the A
# Article generated from prompt: Dear state senator, I as a citizen of florida, and
# Article generated from prompt: When one thinks of transportation, the first idea
# Article generated from prompt: For centuries, we have followed a certain system e
# Article generated from prompt: The use of cars has always affected society greatl
# Article generated from prompt: Imagine constantly coughing. Would you like that?
# Article generated from prompt: Dear, State Senator I have recently read articles
# Article generated from prompt: Dear Florida Senator, I feel as if we, as Florida
# Article generated from prompt: A life filled to the brim of better days is what w
# Article generated from prompt: The Electoral College is a process put into place
# Article generated from prompt: The Electoral College gives certain states, based
# Article generated from prompt: Using a motor vehicle as a source of transportatio
# Article generated from prompt: State Senator, The Electoral College is not a fair
# Article generated from prompt: "You can live in your car, but you can't drive you
# Article generated from prompt: Limiting car usage is a very good idea. It can sav
# Article generated from prompt: Not everyone has the luxury of owning a car. But c
# Article generated from prompt: Almost every American has a car. Just go outside a
# Article generated from prompt: The idea of reducing car usage is a good idea, bec
# Article generated from prompt: The Electoral College is a process made by the fou
# Article generated from prompt: Living in a community without the use of cars can
# Generating articles for batch starting with prompt: Every vote makes a difference. Every single vote p...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Every vote makes a difference. Every single vote p
# Article generated from prompt: The electoral college is unfair to voters. Electin
# Article generated from prompt: Every four years america as a whole chooses on who
# Article generated from prompt: Deaor Mor. Senatoor, What is the Electooral Colleg
# Article generated from prompt: Dear Senator, Electoral college may be a despised
# Article generated from prompt: "The day that mankind realizes that their creation
# Article generated from prompt: Having a car can be very stressful and cost a lot
# Article generated from prompt: Transportation is the second largest source of Ame
# Article generated from prompt: Politics is everywhere and it rules our everyday l
# Article generated from prompt: Dear Mr. Senator, I have decided to express my opi
# Article generated from prompt: The electoral college is a symbol of mockery and d
# Article generated from prompt: There are many advantages to limiting car usage. L
# Article generated from prompt: Dear State Senator, I do not like the Electoral Co
# Article generated from prompt: United States of America, the land of the people r
# Article generated from prompt: For the past few years, people have come to theori
# Article generated from prompt: The system by which America elects its president i
# Article generated from prompt: The Electoral College is outdated, unfair, and irr
# Article generated from prompt: Limiting car usage could come off as absurd to som
# Article generated from prompt: Thinking of the past century ideas of driving cars
# Article generated from prompt: The Electoral Collage has been around for a long t
# Generating articles for batch starting with prompt: In today's society, most people believe that havin...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: In today's society, most people believe that havin
# Article generated from prompt: Cars have been around for awhile and they have had
# Article generated from prompt: Can you tell the air feels different? Over the pas
# Article generated from prompt: Do you think that the Electoral College prosses is
# Article generated from prompt: After World War II cars began to become more and m
# Article generated from prompt: Driving a car around can be very a affective aspec
# Article generated from prompt: Do you own a car? Have you ever driven one? Many p
# Article generated from prompt: Transportation has been a part of society for as l
# Article generated from prompt: Dear Senator PROPER_NAME, As you are well aware, e
# Article generated from prompt: Dear Rick Scott, Every four years on the Tuesday a
# Article generated from prompt: Ah, the electoral college. Don't you just how irre
# Article generated from prompt: Dear State Senate, I feel that the way we, the peo
# Article generated from prompt: Men are like ants. We are always in a rush and alw
# Article generated from prompt: In our society today, limiting car usage would be
# Article generated from prompt: The time of the founding fathers is long gone. Tim
# Article generated from prompt: State Senator, The Electoral College is outdated,
# Article generated from prompt: When cars were first introduced into society it wa
# Article generated from prompt: Limiting car usage will give us many benefits. A p
# Article generated from prompt: Dear Senator, There have been multiple arguments o
# Article generated from prompt: Thier are a bunch of reasons for not using a car I
# Generating articles for batch starting with prompt: The world is facing incredibly drastic climate cha...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: The world is facing incredibly drastic climate cha
# Article generated from prompt: We should keep our method of chosing a president e
# Article generated from prompt: Recently, there have been and more people walking,
# Article generated from prompt: Dear senator, I strongly believe that we should de
# Article generated from prompt: Although a motorized vehicle provides the opportun
# Article generated from prompt: Most people have been riding in cars there whole l
# Article generated from prompt: limiting car usage is an advantage for many reason
# Article generated from prompt: Limiting car usage is the last thing people would
# Article generated from prompt: Dear Florida Senator, Our country, the United Stat
# Article generated from prompt: Sometimes things need to change but not in this ca
# Article generated from prompt: For many years, the automobile has become and rema
# Article generated from prompt: Dear, state Senator Electoral College should be ab
# Article generated from prompt: The Electoral College is a process that has been u
# Article generated from prompt: All around the world different countries have been
# Article generated from prompt: FREEDOM! We are all americans here so we should ha
# Article generated from prompt: Many people are not in favor of keeping the Electo
# Article generated from prompt: In today's society, when people are asked if they
# Article generated from prompt: Dear Senator, I think you should get rid of the El
# Article generated from prompt: Global warming is one of the main reason, maybe th
# Article generated from prompt: imagine a world where global warming could actuall
# Generating articles for batch starting with prompt: Dear State Senator, Once a year, people all over t...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Dear State Senator, Once a year, people all over t
# Article generated from prompt: The electoral college is one of the most heavily c
# Article generated from prompt: The electoral college is how america chooses its p
# Article generated from prompt: It is in the best interest of the people that you
# Article generated from prompt: I think that we should change to popular vote for
# Article generated from prompt: Senator of the State of Florida, The Electoral Col
# Article generated from prompt: Automobiles play a huge role in our everyday life.
# Article generated from prompt: I argue in changing the electoral college , popula
# Article generated from prompt: Dear Senator of the United States, I am a student
# Article generated from prompt: The founding fathers established the Electoral Col
# Article generated from prompt: Every four years, the United States is turned into
# Article generated from prompt: A president election is great but, there are some
# Article generated from prompt: When the US Constitution was first made, the idea
# Article generated from prompt: If we never do anything about the air pollution co
# Article generated from prompt: Limiting car usage is a good idea. Limiting cars u
# Article generated from prompt: After the research I have done I think that changi
# Article generated from prompt: In the United States, the process to pick the pres
# Article generated from prompt: In today's growing world to many it may seem as if
# Article generated from prompt: Cars may actually disappear from the modern world
# Article generated from prompt: Dear Senator the electoral voting system should be
# Generating articles for batch starting with prompt: The Electoral College is how America votes for the...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: The Electoral College is how America votes for the
# Article generated from prompt: To Whom It May Concern, The Electoral College that
# Article generated from prompt: Many people in the world today think that cars and
# Article generated from prompt: The Electoral College, to begin with, is the elect
# Article generated from prompt: The Electoral College is a process by which we vot
# Article generated from prompt: Dear State Senator, I think we should get rid of t
# Article generated from prompt: Countries like France, Columbia, Germany and USA h
# Article generated from prompt: The number of miles driven in the United States pe
# Article generated from prompt: Dear State Senator, Im going to tell you why im in
# Article generated from prompt: Dear Florida Senator, I think we should change our
# Article generated from prompt: Dear United States Senator, Voting in the United S
# Article generated from prompt: There are many advantages of limiting car usage. L
# Article generated from prompt: Cars are seen as a necessity due to the fact that
# Article generated from prompt: There have been many discussions whether or not ha
# Article generated from prompt: The presidential Elections. The elections are a br
# Article generated from prompt: Limiting the usage of cars has personal and profes
# Article generated from prompt: Dear senator, I believe the Electoral College Syst
# Article generated from prompt: Dear Mr. Senator, After reviewing information abou
# Article generated from prompt: For many years now people have been cutting down o
# Article generated from prompt: Dear senator, We should change the electoral colle
# Generating articles for batch starting with prompt: Cars! Cars! Cars! Some might say that you cant eve...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Cars! Cars! Cars! Some might say that you cant eve
# Article generated from prompt: Many people use cars to get from one place to anot
# Article generated from prompt: The Electoral College is the cause of many politic
# Article generated from prompt: Dear Florida State Senator, It has been brought to
# Article generated from prompt: The black smoke that leaks out of your car's tailp
# Article generated from prompt: Throughout the decades of humans being on earth, w
# Article generated from prompt: Could you imagine what it would be like if we limi
# Article generated from prompt: It'd be better to stay with the Electoral College
# Article generated from prompt: In my opinion, I think that the Electoral College
# Article generated from prompt: Florida Senator I had not known much about the ele
# Article generated from prompt: Dear Senator, The electoral college is unfair, out
# Article generated from prompt: There have been a few close calls during our presi
# Article generated from prompt: Normally in everyone's mind when they are a teenag
# Article generated from prompt: Dear Senator, The electoral college is a process t
# Article generated from prompt: Driving is the primary way of transportation, to g
# Article generated from prompt: Dear Florida State Senator, The Electoral College
# Article generated from prompt: Limiting car usage is beneficial to more than just
# Article generated from prompt: Cars have been popular and widely used ever since
# Article generated from prompt: For more than a hundred years now, we have been re
# Article generated from prompt: Cars are the main cause of pollution in major citi
# Generating articles for batch starting with prompt: Throughout time, pollution has been known to be a ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Article generated from prompt: Throughout time, pollution has been known to be a
# Article generated from prompt: People all over the United States, even the world,
# Article generated from prompt: Cars have been a part of our culture for some time
# Article generated from prompt: Dear Senator, I, STUDENT_NAME, am in favor of chan
# Article generated from prompt: Dear State Senator, I argue in favor of keeping th
# Article generated from prompt: Limiting car usage can put a new perspective in yo
# Article generated from prompt: "Life goes on without cars."Rosenthal.There are ma
# Article generated from prompt: People all over the world are saying goodbye to th
# Article generated from prompt: Dear State Senator, The Electoral College is a pro
# Article generated from prompt: Dear State Senator , I wrote this letter to you to
# Article generated from prompt: Dear Mr.Mrs. Senator, The Electoral College is a p
# Article generated from prompt: Even though the Electoral College is known as a di
# Article generated from prompt: Not a day goes by that you don't see a car passing
# Article generated from prompt: Dear, state senator I think we should change to el
# Article generated from prompt: When you vote for president you want to vote for w
# Generated articles saved to /content/drive/My Drive/ML Project data/output_file_GPT-2(O4).xlsx
